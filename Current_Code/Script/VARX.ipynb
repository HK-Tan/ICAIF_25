# %% [markdown]
# ## Vanilla VAR and VARX Set-up and Evaluation

# %%
### Data Processing

## Ignore warnings
import warnings
warnings.filterwarnings("ignore")
# Helper imports
import numpy as np
import pandas as pd
import os
import sys

from functools import reduce
import matplotlib.pyplot as plt

# %matplotlib inline

current_working_dir = os.getcwd()
print(f"Current Working Directory: {current_working_dir}")
project_root = os.path.dirname(current_working_dir)
modules_path = os.path.join(project_root, 'Modules')
if modules_path not in sys.path:
    sys.path.append(modules_path)
    print(f"Added to sys.path for custom modules: {modules_path}")

####################################################################
#### NYSE Daily Open-Close Returns
####################################################################
data_folder_path = os.path.join(project_root, 'Data')
data_file_name = "OPCL_20000103_20201231.csv"   
data_file_path = os.path.join(data_folder_path, data_file_name) # So that we get to the file itself and not the folder it is in
returns_df = pd.read_csv(data_file_path) # Assumes file exists and is readable
returns_df.set_index('ticker', inplace=True)
returns_df.columns = pd.to_datetime(returns_df.columns.str.lstrip('X'), format='%Y%m%d').strftime('%Y-%m-%d')
returns_df_cleaned = returns_df.dropna().transpose() # Assumes dropna results in non-empty returns_df
returns_df_cleaned.index = pd.to_datetime(returns_df_cleaned.index)
returns_df_cleaned.index.name = 'date'
print("Data loaded and cleaned. Sample (first 5 rows/cols):")
print(returns_df_cleaned.iloc[0:5,0:5])
print(f"Shape of the cleaned data: {returns_df_cleaned.shape}")

####################################################################
#### Constructing the dataframe for the Confounding Variables
####################################################################

"""
Data Source: Federal Reserve Economic Data (FRED)

DFF -> Federal Funds Effective Rate
T5YIE -> 5-Year Breakeven Inflation Rate (only from 2003)
USEPUINDXD -> Economic Policy Uncertainty Index for United States; News-based, 7 days moving average
VIX -> CBOE Volatility Index (VIX)
DCOILWTICO -> West Texas Intermediate (WTI) Crude Oil Prices: Cushing, Oklahoma
DTWEXBGS -> Broad U.S. Dollar Index: Trade Weighted Exchange Rate Index for Major Currencies (only from 2006)
DTWEXEMEGS-> Broad U.S. Dollar Index: Trade Weighted Exchange Rate Index for Emerging Market Economies (only from 2006)

Other Potential Data Sources:
Gold Prices (Futures/Spot), etc.
"""

files = ["DFF_20000103_20201231.csv",
         "T5YIE_20030102_20201231.csv",
         "USEPUINDXD_20000103_20201231.csv",
         "VIX_20000103_20201231.csv",
         "DCOILWTICO_20000103_20201231.csv",
         "DTWEXBGS_20060102_20201231.csv",
         "DTWEXEMEGS_20060102_20201231.csv"
         ]


merged_confound_df = reduce(
    lambda left, right: pd.merge(left, right, on="observation_date", how="outer"),
    (pd.read_csv(os.path.join(data_folder_path, f), parse_dates=[0]) for f in files)
)
imputed_confound_df = merged_confound_df.interpolate(method='linear', limit_direction='both')
imputed_confound_df.set_index('observation_date', inplace=True)
imputed_confound_df.index.name = 'date'  # Renaming index to 'date'
print("Confounding Variables DataFrame constructed and cleaned. Sample (first 5 rows/cols):")
print(imputed_confound_df.iloc[0:5,:])
print(f"Shape of the cleaned confounding variables data: {imputed_confound_df.shape}")
filtered_confound_df = imputed_confound_df[imputed_confound_df.index.isin(returns_df_cleaned.index)]
print("\n")
print("Filtering by trading dates ...")
print("\n")
print("Filtered Confounding Variables DataFrame:")
print(filtered_confound_df.head())
print(f"Shape of the filtered confounding variables data: {filtered_confound_df.shape}")

from VAR_tools import *

returns_df_cleaned_prep = returns_df_cleaned.iloc[-1300:,:20]
#returns_df_cleaned_prep = returns_df_cleaned.iloc[-1020:,:20]
filtered_confound_df_prep = filtered_confound_df.loc[returns_df_cleaned_prep.index]
print(filtered_confound_df_prep.head())
print(filtered_confound_df_prep.shape)
# Out:
# Current Working Directory: c:\Users\hktan\OneDrive - University of California\Codes\ICAIF_25\Current_Code\Script
# Added to sys.path for custom modules: c:\Users\hktan\OneDrive - University of California\Codes\ICAIF_25\Current_Code\Modules
# Data loaded and cleaned. Sample (first 5 rows/cols):
# ticker            AA       ABM       ABT       ADI       ADM
# date
# 2000-01-03 -0.013042 -0.009188 -0.007117 -0.036071  0.000000
# 2000-01-04  0.010043  0.012346 -0.012786 -0.044261  0.005277
# 2000-01-05  0.047628 -0.006192  0.011111  0.014493 -0.015915
# 2000-01-06 -0.011713  0.000000  0.032553 -0.027719  0.010695
# 2000-01-07 -0.016118  0.003091  0.028573  0.033654  0.005249
# Shape of the cleaned data: (5279, 663)
# Confounding Variables DataFrame constructed and cleaned. Sample (first 5 rows/cols):
#              DFF  T5YIE  USEPUINDXD  VIXCLS  DCOILWTICO  DTWEXBGS  DTWEXEMEGS
# date
# 2000-01-01  3.99    1.3       68.04   24.21       25.56  101.4155    100.9386
# 2000-01-02  3.99    1.3      119.36   24.21       25.56  101.4155    100.9386
# 2000-01-03  5.43    1.3       35.73   24.21       25.56  101.4155    100.9386
# 2000-01-04  5.38    1.3      109.31   27.01       25.56  101.4155    100.9386
# 2000-01-05  5.41    1.3      123.22   26.41       24.65  101.4155    100.9386
# Shape of the cleaned confounding variables data: (7671, 7)
#
#
# Filtering by trading dates ...
#
#
# Filtered Confounding Variables DataFrame:
#              DFF  T5YIE  USEPUINDXD  VIXCLS  DCOILWTICO  DTWEXBGS  DTWEXEMEGS
# date
# 2000-01-03  5.43    1.3       35.73   24.21       25.56  101.4155    100.9386
# 2000-01-04  5.38    1.3      109.31   27.01       25.56  101.4155    100.9386
# 2000-01-05  5.41    1.3      123.22   26.41       24.65  101.4155    100.9386
# 2000-01-06  5.54    1.3       53.61   25.73       24.79  101.4155    100.9386
# 2000-01-07  5.61    1.3       42.03   21.72       24.79  101.4155    100.9386
# Shape of the filtered confounding variables data: (5279, 7)
#              DFF  T5YIE  USEPUINDXD  VIXCLS  DCOILWTICO  DTWEXBGS  DTWEXEMEGS
# date
# 2015-11-02  0.12   1.23       32.86   14.15       46.12  110.2188    112.4965
# 2015-11-03  0.12   1.27       72.75   14.54       47.88  110.2440    112.1118
# 2015-11-04  0.12   1.26       45.24   15.51       46.32  110.7139    112.5096
# 2015-11-05  0.12   1.23       33.09   15.05       45.27  110.8302    112.6224
# 2015-11-06  0.12   1.25       78.78   14.33       44.32  111.7603    113.2503
# (1300, 7)

# %%
import time

# Record start time
start_time = time.perf_counter()

# VARX
results = rolling_window_VAR(
    asset_df=returns_df_cleaned_prep,
    #confound_df=filtered_confound_df_prep,
    days_valid=2,
    model_type = 'lasso'
)


# Calculate and display execution time
end_time = time.perf_counter()
execution_time = end_time - start_time

print(f"rolling_window_OR_VAR() execution time: {execution_time:.2f} seconds")
print(f"rolling_window_OR_VAR() execution time: {execution_time/60:.2f} minutes")

# Store timing results for later analysis
results['execution_time_seconds'] = execution_time
# Out:
# Starting VAR analysis with LASSO model
# Dataset: 1300 days, Test period: 291 days
# Processing day 1008 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0127
# Processing day 1009 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0104
# Processing day 1010 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0117
# Processing day 1011 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0115
# Processing day 1012 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0075
# Processing day 1013 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0082
# Processing day 1014 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0100
# Processing day 1015 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0087
# Processing day 1016 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0071
# Processing day 1017 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0085
# Processing day 1018 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0097
# Processing day 1019 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0089
# Processing day 1020 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0088
# Processing day 1021 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0089
# Processing day 1022 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0095
# Processing day 1023 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0125
# Processing day 1024 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0111
# Processing day 1025 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0070
# Processing day 1026 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0110
# Processing day 1027 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0108
# Processing day 1028 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0082
# Processing day 1029 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0079
# Processing day 1030 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0061
# Processing day 1031 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0080
# Processing day 1032 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0085
# Processing day 1033 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0079
# Processing day 1034 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0121
# Processing day 1035 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0143
# Processing day 1036 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0146
# Processing day 1037 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0147
# Processing day 1038 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0115
# Processing day 1039 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0161
# Processing day 1040 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0192
# Processing day 1041 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0195
# Processing day 1042 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0141
# Processing day 1043 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0073
# Processing day 1044 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0079
# Processing day 1045 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0071
# Processing day 1046 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0078
# Processing day 1047 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0098
# Processing day 1048 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0106
# Processing day 1049 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0099
# Processing day 1050 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0084
# Processing day 1051 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0104
# Processing day 1052 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0118
# Processing day 1053 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0110
# Processing day 1054 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0131
# Processing day 1055 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0124
# Processing day 1056 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0107
# Processing day 1057 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0158
# Processing day 1058 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0153
# Processing day 1059 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0106
# Processing day 1060 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0126
# Processing day 1061 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0122
# Processing day 1062 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0142
# Processing day 1063 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0138
# Processing day 1064 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0099
# Processing day 1065 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0102
# Processing day 1066 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0112
# Processing day 1067 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0137
# Processing day 1068 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0117
# Processing day 1069 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0151
# Processing day 1070 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0177
# Processing day 1071 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0134
# Processing day 1072 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0141
# Processing day 1073 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0116
# Processing day 1074 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0110
# Processing day 1075 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0105
# Processing day 1076 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0152
# Processing day 1077 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0182
# Processing day 1078 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0122
# Processing day 1079 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0110
# Processing day 1080 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0147
# Processing day 1081 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0138
# Processing day 1082 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0121
# Processing day 1083 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0294
# Processing day 1084 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0328
# Processing day 1085 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0279
# Processing day 1086 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0318
# Processing day 1087 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0356
# Processing day 1088 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0373
# Processing day 1089 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0272
# Processing day 1090 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0256
# Processing day 1091 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0299
# Processing day 1092 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0367
# Processing day 1093 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0314
# Processing day 1094 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0302
# Processing day 1095 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0606
# Processing day 1096 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0755
# Processing day 1097 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0785
# Processing day 1098 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0801
# Processing day 1099 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0964
# Processing day 1100 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.1145
# Processing day 1101 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0988
# Processing day 1102 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0656
# Processing day 1103 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0534
# Processing day 1104 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0760
# Processing day 1105 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0787
# Processing day 1106 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0560
# Processing day 1107 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0392
# Processing day 1108 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0299
# Processing day 1109 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0268
# Processing day 1110 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0332
# Processing day 1111 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0386
# Processing day 1112 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0424
# Processing day 1113 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0405
# Processing day 1114 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0381
# Processing day 1115 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0365
# Processing day 1116 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0384
# Processing day 1117 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0323
# Processing day 1118 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0237
# Processing day 1119 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0267
# Processing day 1120 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0263
# Processing day 1121 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0277
# Processing day 1122 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0242
# Processing day 1123 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0207
# Processing day 1124 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0257
# Processing day 1125 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0237
# Processing day 1126 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0205
# Processing day 1127 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0266
# Processing day 1128 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0282
# Processing day 1129 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0263
# Processing day 1130 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0268
# Processing day 1131 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0244
# Processing day 1132 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0223
# Processing day 1133 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0316
# Processing day 1134 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0338
# Processing day 1135 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0291
# Processing day 1136 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0251
# Processing day 1137 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0316
# Processing day 1138 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0407
# Processing day 1139 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0346
# Processing day 1140 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0243
# Processing day 1141 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0286
# Processing day 1142 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0299
# Processing day 1143 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0197
# Processing day 1144 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0203
# Processing day 1145 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0163
# Processing day 1146 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0185
# Processing day 1147 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0295
# Processing day 1148 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0321
# Processing day 1149 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0273
# Processing day 1150 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0219
# Processing day 1151 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0191
# Processing day 1152 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0307
# Processing day 1153 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0400
# Processing day 1154 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0364
# Processing day 1155 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0336
# Processing day 1156 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0257
# Processing day 1157 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0283
# Processing day 1158 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0385
# Processing day 1159 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0309
# Processing day 1160 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0354
# Processing day 1161 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0385
# Processing day 1162 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0268
# Processing day 1163 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0264
# Processing day 1164 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0341
# Processing day 1165 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0292
# Processing day 1166 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0173
# Processing day 1167 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0257
# Processing day 1168 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0334
# Processing day 1169 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0281
# Processing day 1170 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0250
# Processing day 1171 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0232
# Processing day 1172 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0218
# Processing day 1173 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0221
# Processing day 1174 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0180
# Processing day 1175 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0206
# Processing day 1176 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0250
# Processing day 1177 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0285
# Processing day 1178 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0354
# Processing day 1179 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0291
# Processing day 1180 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0267
# Processing day 1181 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0233
# Processing day 1182 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0161
# Processing day 1183 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0188
# Processing day 1184 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0185
# Processing day 1185 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0148
# Processing day 1186 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0142
# Processing day 1187 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0143
# Processing day 1188 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0159
# Processing day 1189 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0198
# Processing day 1190 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0181
# Processing day 1191 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0187
# Processing day 1192 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0223
# Processing day 1193 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0205
# Processing day 1194 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0162
# Processing day 1195 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0177
# Processing day 1196 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0193
# Processing day 1197 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0205
# Processing day 1198 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0255
# Processing day 1199 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0262
# Processing day 1200 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0256
# Processing day 1201 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0255
# Processing day 1202 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0174
# Processing day 1203 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0133
# Processing day 1204 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0173
# Processing day 1205 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0153
# Processing day 1206 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0130
# Processing day 1207 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0133
# Processing day 1208 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0118
# Processing day 1209 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0166
# Processing day 1210 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0172
# Processing day 1211 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0138
# Processing day 1212 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0161
# Processing day 1213 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0161
# Processing day 1214 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0158
# Processing day 1215 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0193
# Processing day 1216 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0207
# Processing day 1217 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0218
# Processing day 1218 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0195
# Processing day 1219 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0164
# Processing day 1220 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0183
# Processing day 1221 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0194
# Processing day 1222 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0177
# Processing day 1223 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0166
# Processing day 1224 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0174
# Processing day 1225 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0167
# Processing day 1226 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0192
# Processing day 1227 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0184
# Processing day 1228 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0202
# Processing day 1229 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0192
# Processing day 1230 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0252
# Processing day 1231 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0275
# Processing day 1232 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0211
# Processing day 1233 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0180
# Processing day 1234 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0142
# Processing day 1235 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0138
# Processing day 1236 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0138
# Processing day 1237 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0259
# Processing day 1238 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0242
# Processing day 1239 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0177
# Processing day 1240 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0164
# Processing day 1241 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0124
# Processing day 1242 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0148
# Processing day 1243 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0135
# Processing day 1244 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0159
# Processing day 1245 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0151
# Processing day 1246 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0176
# Processing day 1247 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0200
# Processing day 1248 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0171
# Processing day 1249 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0123
# Processing day 1250 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0109
# Processing day 1251 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0188
# Processing day 1252 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0167
# Processing day 1253 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0151
# Processing day 1254 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0207
# Processing day 1255 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0216
# Processing day 1256 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0243
# Processing day 1257 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0235
# Processing day 1258 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0178
# Processing day 1259 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0196
# Processing day 1260 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0220
# Processing day 1261 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0274
# Processing day 1262 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0268
# Processing day 1263 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0252
# Processing day 1264 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0274
# Processing day 1265 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0216
# Processing day 1266 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0166
# Processing day 1267 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0195
# Processing day 1268 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0201
# Processing day 1269 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0191
# Processing day 1270 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0228
# Processing day 1271 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0199
# Processing day 1272 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0126
# Processing day 1273 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0163
# Processing day 1274 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0207
# Processing day 1275 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0125
# Processing day 1276 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0093
# Processing day 1277 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0153
# Processing day 1278 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0195
# Processing day 1279 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0212
# Processing day 1280 out of 1299 days in the dataset.
# Optimal parameters: p=3, alpha=0.001, validation RMSE=0.0183
# Processing day 1281 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0180
# Processing day 1282 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0196
# Processing day 1283 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0174
# Processing day 1284 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0168
# Processing day 1285 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0179
# Processing day 1286 out of 1299 days in the dataset.
# Optimal parameters: p=4, alpha=0.001, validation RMSE=0.0166
# Processing day 1287 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0197
# Processing day 1288 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0290
# Processing day 1289 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0276
# Processing day 1290 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0176
# Processing day 1291 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0149
# Processing day 1292 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0204
# Processing day 1293 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0175
# Processing day 1294 out of 1299 days in the dataset.
# Optimal parameters: p=5, alpha=0.001, validation RMSE=0.0127
# Processing day 1295 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0108
# Processing day 1296 out of 1299 days in the dataset.
# Optimal parameters: p=2, alpha=0.001, validation RMSE=0.0095
# Processing day 1297 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0114
# Processing day 1298 out of 1299 days in the dataset.
# Optimal parameters: p=1, alpha=0.001, validation RMSE=0.0128
# VAR analysis completed. Processed 291 days.
# rolling_window_OR_VAR() execution time: 124.79 seconds
# rolling_window_OR_VAR() execution time: 2.08 minutes

# %%
import pickle

# Save the dictionary
# with open('result_3.pkl', 'wb') as f:
#     pickle.dump(results, f)

# Load the dictionary
with open('result_3.pkl', 'rb') as f:
    results = pickle.load(f)

## _3 for VARX w/ OLS

# %%
import pickle

# Save the dictionary
with open('result_4.pkl', 'wb') as f:
    pickle.dump(results, f)

# Load the dictionary
with open('result_4.pkl', 'rb') as f:
    results = pickle.load(f)


## _4 for VARX w/ Laaso

# %%
import pickle

# Save the dictionary
with open('result_5.pkl', 'wb') as f:
    pickle.dump(results, f)

# Load the dictionary
with open('result_5.pkl', 'rb') as f:
    results = pickle.load(f)


## _5 for VAR without confounding variables, OLS

# %%
import pickle

# Save the dictionary
with open('result_6.pkl', 'wb') as f:
    pickle.dump(results, f)

# Load the dictionary
with open('result_6.pkl', 'rb') as f:
    results = pickle.load(f)


## _6 for VAR without confounding variables, LASSO

# %% [markdown]
# ### Plots and Errors

# %%
import matplotlib.pyplot as plt
import numpy as np

# Extract p_optimal from your results dictionary
p_optimal = results['p_optimal']
days = np.arange(len(p_optimal))

# Create the plot
plt.figure(figsize=(15, 6))
plt.bar(days, p_optimal)
plt.xlabel('Day')
plt.ylabel('p_optimal Value')
plt.title('p_optimal Values Over Time')
plt.grid(True, alpha=0.3)
plt.show()

# %%
from DML_tools import calculate_pnl

forecasted_returns = pd.DataFrame(results['Y_hat_next_store'],
                                  index=returns_df_cleaned_prep.index[-1300+252*4+1:], 
                                  #index=returns_df_cleaned_prep.index[-1020+252*4+1:], 
                                  columns=returns_df_cleaned_prep.columns)
actual_returns = returns_df_cleaned_prep.iloc[-1300+252*4+1:,:20]
#actual_returns = returns_df_cleaned_prep.iloc[-1020+252*4+1:,:20]
print(forecasted_returns.shape)
print(actual_returns.shape)

pnl_series_n, pnl_per_n = calculate_pnl(forecasted_returns, actual_returns, contrarian = False, pnl_strategy="naive")
pnl_series_w, pnl_per_w = calculate_pnl(forecasted_returns, actual_returns, contrarian = False, pnl_strategy="weighted")
pnl_series_t, pnl_per_t = calculate_pnl(forecasted_returns, actual_returns, contrarian = False, pnl_strategy="top")

import matplotlib.pyplot as plt

# Create the plot
plt.figure(figsize=(12, 6))
plt.plot(pnl_series_n, color='blue', label='Naive Strategy', linewidth=2)
plt.plot(pnl_series_w, color='red', label='Weighted Strategy', linewidth=2)
plt.plot(pnl_series_t, color='green', label='Top Strategy', linewidth=2)

# Customize the plot
plt.title('PnL Comparison Across Different Strategies', fontsize=16)
plt.xlabel('Time', fontsize=12)
plt.ylabel('PnL', fontsize=12)
plt.legend(loc='best')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.savefig('pnl_comparison.png')
plt.show()

def get_metrics(series, perc):
    # For a compounding PnL series, daily returns are the percentage change.
    daily_rets = perc.dropna()

    # Calculate Compound Annual Growth Rate (CAGR)
    total_return = series.iloc[-1] 
    ann_ret = (1 + total_return) ** (252 / len(series)) - 1

    # Sharpe ratio calculation remains valid with the corrected daily returns.
    # We assume a risk-free rate of 0 for this calculation.
    sharpe = (daily_rets.mean() * 252) / (daily_rets.std() * np.sqrt(252))
    return ann_ret * 100, sharpe

# Get metrics for all strategies
for name, series, perc in [("Naive", pnl_series_n, pnl_per_n), ("Weighted", pnl_series_w, pnl_per_w), ("Top", pnl_series_t, pnl_per_t)]:
    ann_ret, sharpe = get_metrics(series, perc)
    print(f"{name}: {ann_ret:.4f}% annualized, Sharpe: {sharpe:.4f}")
# Out:
# (291, 20)
# (291, 20)
# Daily portfolio returns (percentage change): date
# 2019-11-06    0.004071
# 2019-11-07   -0.004834
# 2019-11-08    0.002930
# 2019-11-11    0.001657
# 2019-11-12    0.004891
#                 ...
# 2020-12-24    0.001858
# 2020-12-28   -0.000150
# 2020-12-29    0.001215
# 2020-12-30   -0.006533
# 2020-12-31    0.002320
# Length: 291, dtype: float64
# Daily portfolio returns (percentage change): date
# 2019-11-06    0.004135
# 2019-11-07   -0.005573
# 2019-11-08    0.003155
# 2019-11-11    0.002850
# 2019-11-12    0.005300
#                 ...
# 2020-12-24    0.005499
# 2020-12-28    0.000470
# 2020-12-29    0.006604
# 2020-12-30   -0.011903
# 2020-12-31    0.003714
# Length: 291, dtype: float64
# Daily portfolio returns (percentage change): date
# 2019-11-06    0.001421
# 2019-11-07   -0.008683
# 2019-11-08    0.005886
# 2019-11-11    0.002277
# 2019-11-12    0.004142
#                 ...
# 2020-12-24    0.005380
# 2020-12-28    0.000638
# 2020-12-29    0.008149
# 2020-12-30   -0.014251
# 2020-12-31   -0.003965
# Length: 291, dtype: float64
# Naive: -9.5521% annualized, Sharpe: -0.7162
# Weighted: -10.0409% annualized, Sharpe: -0.3856
# Top: -40.4715% annualized, Sharpe: -2.1692
